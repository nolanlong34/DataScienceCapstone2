# %%
#load packages
import os
import pandas as pd

# %%
#loads dataframe
df = pd.read_excel('apartment_data.xlsx')

# %%
df.head()
# Out:
#            id                category                            title  \
# 0  5668640009  housing/rent/apartment       One BR 507 & 509 Esplanade
# 1  5668639818  housing/rent/apartment      Three BR 146 Lochview Drive
# 2  5668639686  housing/rent/apartment  Three BR 3101 Morningside Drive
# 3  5668639659  housing/rent/apartment            Two BR 209 Aegean Way
# 4  5668639374  housing/rent/apartment         One BR 4805 Marquette NE
#
#                                                 body amenities  bathrooms  \
# 0  This unit is located at 507 & 509 Esplanade, R...       NaN        1.0
# 1  This unit is located at 146 Lochview Drive, Ne...       NaN        1.5
# 2  This unit is located at 3101 Morningside Drive...       NaN        2.0
# 3  This unit is located at 209 Aegean Way, Vacavi...       NaN        1.0
# 4  This unit is located at 4805 Marquette NE, Alb...       NaN        1.0
#
#    bedrooms currency fee  has_photo  ... price_display  price_type  \
# ...

# %%
#creates dataframe with listing only in USD and then removes currenct column
usd_df = df.loc[df['currency'] == 'USD']
apt_df = usd_df.drop('currency', axis=1)

# %%
#creates dataframe with only apartments for rent then removes category column
apartment_df = apt_df.loc[df['category'] == 'housing/rent/apartment']
apt_rent_df= apartment_df.drop('category', axis=1)

# %%
#drops columns not needed
clean_apt_df= apt_rent_df.drop(['has_photo','amenities','fee','price_display','price_type'], axis=1)

# %%
#makes time column human readable
clean_apt_df['time'] = pd.to_datetime(clean_apt_df['time'], unit='s')

# %%
#removes duplicate entries from the dataset
clean_apt_df = clean_apt_df.drop_duplicates()

# %%
clean_apt_df = clean_apt_df.drop('source', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 clean_apt_df = clean_apt_df.drop('source', axis=1)
#
# File c:\Users\Nolan\Anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
# ...

# %%
#saves as a new file
clean_apt_df.to_excel('clean_apt_data.xlsx', index=False)
